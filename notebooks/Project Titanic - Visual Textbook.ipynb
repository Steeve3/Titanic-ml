# %% [markdown]
# <a href="https://colab.research.google.com/github/Steeve3/Titanic-ml/blob/main/notebooks/Project%20Titanic%20-%20Visual%20Textbook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Introduction

# %% [markdown]
# # 2. Load Data
# In this project dataset is downloaded using Kaggle API. This for the purpose on understanding how it can be done for future projects. Then after the loading of data and the set up, we will proceed with the exploration of the data.

# %%
# !pip install kaggle -quiet

# %%
# Upload the file with the access token
from google.colab import files
import os, shutil

# Upload the access_token file you downloaded from Kaggle
files.upload()  # select kaggle.json containing {"username":"xx","key":"KEY"}
# Out:
#      <input type="file" id="files-e29ec2f9-81fd-4072-9cd1-6e53d57e08d3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e29ec2f9-81fd-4072-9cd1-6e53d57e08d3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# create kaggle directory
# !mkdir ~/.kaggle
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
#copy the file in the kaggle folder
# !cp kaggle.json ~/.kaggle

# %%
# check the permissions
# !ls -ltr ~/.kaggle
# Out:
# total 4
# -rw-r--r-- 1 root root 72 Nov 23 17:58 kaggle.json

# %%
# change the permissions
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !ls -ltr ~/.kaggle
# Out:
# total 4
# -rw------- 1 root root 72 Nov 23 17:58 kaggle.json

# %%
#download Titanic competition
# !kaggle competitions download titanic -w -o -q
# !unzip -o data/titanic.zip -d data/
# Out:
# 401 Client Error: Unauthorized for url: https://www.kaggle.com/api/v1/competitions/data/download-all/titanic

# %% [markdown]
# # 3. EDA

# %% [markdown]
# I just set my Kaggle API token for this session in Colab. Now the data are accessible for EDA.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

rw_training = pd.read_csv('/content/data/train.csv')
rw_test = pd.read_csv('/content/data/test.csv')
print('Here the dataset: \nTraining size {}, \nTest size {}'.format(rw_training.shape, rw_test.shape))
# Out:
# Here the dataset:
# Training size (891, 12),
# Test size (418, 11)

# %% [markdown]
# ## Short exploration of the Traning Set

# %%
rw_training.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
rw_training.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
rw_training.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ## Short Exploration of the Test set

# %% [markdown]
# #5. Feature Engineering
# #6. Train/Test Split
# #7. Modeling Pipelines
# #8. Perceptron
# #9. KNN
# #10. SVM (Linear & RBF)
# #11. Logistic Regression
# #12. Decision Tree
# #13. Random Forest
# #14. Neural Network (MLP)
# #15. Hyperparameter Tuning
# #16. Model Comparison
# #17. Conclusion
# #18. Appendix (Theory Images)
