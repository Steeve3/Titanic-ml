# %% [markdown]
# 1. Introduction
# 2. Load Data
# 3. EDA
# 4. Data Cleaning
# 5. Feature Engineering
# 6. Train/Test Split
# 7. Modeling Pipelines
# 8. Perceptron
# 9. KNN
# 10. SVM (Linear & RBF)
# 11. Logistic Regression
# 12. Decision Tree
# 13. Random Forest
# 14. Neural Network (MLP)
# 15. Hyperparameter Tuning
# 16. Model Comparison
# 17. Conclusion
# 18. Appendix (Theory Images)

# %% [markdown]
# !python src/data/download_data.py
